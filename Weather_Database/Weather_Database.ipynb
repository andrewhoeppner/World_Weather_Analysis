# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a04735a07a915b00c8cd5e49afde673a

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the Latitude and Longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, add it to the cities list.
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 726

# %%
# Create an empty list to hold the weather data.
city_data = []

# %%
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
#loop through cities in list
for i, city in enumerate(cities):
    
    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #create URL endpoint for city
    city_url = url + '&q=' + city.replace(" ","+")
    
    #log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # add 1 to record count
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_dc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_dc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | avarua
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | thompson
# Processing Record 4 of Set 1 | katsuura
# Processing Record 5 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | umm kaddadah
# Processing Record 8 of Set 1 | hasaki
# Processing Record 9 of Set 1 | ler
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | kavieng
# Processing Record 12 of Set 1 | kihei
# Processing Record 13 of Set 1 | saint george
# Processing Record 14 of Set 1 | aldan
# Processing Record 15 of Set 1 | port alfred
# Processing Record 16 of Set 1 | victoria
# Processing Record 17 of Set 1 | kaitangata
# Processing Record 18 of Set 1 | guerrero negro
# Processing Record 19 of Set 1 | goundi
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | bluff
# Processing Record 22 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 1 | dingle
# Processing Record 24 of Set 1 | hermanus
# Processing Record 25 of Set 1 | okhotsk
# Processing Record 26 of Set 1 | ilinge
# Processing Record 27 of Set 1 | tutoia
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 1 | podbelsk
# City not found. Skipping...
# Processing Record 30 of Set 1 | mahebourg
# Processing Record 31 of Set 1 | leningradskiy
# Processing Record 32 of Set 1 | qaanaaq
# Processing Record 33 of Set 1 | narsaq
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | progreso
# Processing Record 37 of Set 1 | rikitea
# Processing Record 38 of Set 1 | shediac
# Processing Record 39 of Set 1 | saskylakh
# Processing Record 40 of Set 1 | albany
# Processing Record 41 of Set 1 | bambous virieux
# Processing Record 42 of Set 1 | puerto ayora
# Processing Record 43 of Set 1 | taraz
# Processing Record 44 of Set 1 | evensk
# Processing Record 45 of Set 1 | kenai
# Processing Record 46 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 1 | aklavik
# Processing Record 48 of Set 1 | cooma
# Processing Record 49 of Set 1 | ancud
# Processing Record 50 of Set 1 | new norfolk
# Processing Record 1 of Set 2 | mackay
# Processing Record 2 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 2 | yellowknife
# Processing Record 4 of Set 2 | castro
# Processing Record 5 of Set 2 | tazovskiy
# Processing Record 6 of Set 2 | tuatapere
# Processing Record 7 of Set 2 | vaini
# Processing Record 8 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 9 of Set 2 | muana
# Processing Record 10 of Set 2 | nong chik
# Processing Record 11 of Set 2 | champerico
# Processing Record 12 of Set 2 | nizwa
# Processing Record 13 of Set 2 | tevaitoa
# Processing Record 14 of Set 2 | nikolskoye
# Processing Record 15 of Set 2 | mar del plata
# Processing Record 16 of Set 2 | milton
# Processing Record 17 of Set 2 | kamaishi
# Processing Record 18 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 2 | cap malheureux
# Processing Record 20 of Set 2 | dzaoudzi
# Processing Record 21 of Set 2 | rawson
# Processing Record 22 of Set 2 | butaritari
# Processing Record 23 of Set 2 | ozernovskiy
# Processing Record 24 of Set 2 | klaksvik
# Processing Record 25 of Set 2 | grand gaube
# Processing Record 26 of Set 2 | leshukonskoye
# Processing Record 27 of Set 2 | beloha
# Processing Record 28 of Set 2 | oak ridge
# Processing Record 29 of Set 2 | boa vista
# Processing Record 30 of Set 2 | fortuna
# Processing Record 31 of Set 2 | doha
# Processing Record 32 of Set 2 | mayumba
# Processing Record 33 of Set 2 | turukhansk
# Processing Record 34 of Set 2 | kapaa
# Processing Record 35 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 2 | carnarvon
# Processing Record 38 of Set 2 | iqaluit
# Processing Record 39 of Set 2 | nenjiang
# Processing Record 40 of Set 2 | hovd
# Processing Record 41 of Set 2 | tuktoyaktuk
# Processing Record 42 of Set 2 | bud
# Processing Record 43 of Set 2 | bredasdorp
# Processing Record 44 of Set 2 | aksarka
# Processing Record 45 of Set 2 | te anau
# Processing Record 46 of Set 2 | thinadhoo
# Processing Record 47 of Set 2 | barrow
# Processing Record 48 of Set 2 | lorengau
# Processing Record 49 of Set 2 | okato
# Processing Record 50 of Set 2 | saint-philippe
# Processing Record 1 of Set 3 | najran
# Processing Record 2 of Set 3 | san quintin
# Processing Record 3 of Set 3 | lazaro cardenas
# Processing Record 4 of Set 3 | aranos
# Processing Record 5 of Set 3 | manokwari
# Processing Record 6 of Set 3 | yumen
# Processing Record 7 of Set 3 | gurgan
# City not found. Skipping...
# Processing Record 8 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 3 | castillo de teayo
# Processing Record 10 of Set 3 | arraial do cabo
# Processing Record 11 of Set 3 | ye
# City not found. Skipping...
# Processing Record 12 of Set 3 | ceres
# Processing Record 13 of Set 3 | alofi
# Processing Record 14 of Set 3 | morondava
# Processing Record 15 of Set 3 | hilo
# Processing Record 16 of Set 3 | pisco
# Processing Record 17 of Set 3 | itarema
# Processing Record 18 of Set 3 | georgetown
# Processing Record 19 of Set 3 | severo-kurilsk
# Processing Record 20 of Set 3 | nuevo progreso
# Processing Record 21 of Set 3 | port elizabeth
# Processing Record 22 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 24 of Set 3 | lucapa
# Processing Record 25 of Set 3 | bandarbeyla
# Processing Record 26 of Set 3 | lompoc
# Processing Record 27 of Set 3 | bengkulu
# Processing Record 28 of Set 3 | kodiak
# Processing Record 29 of Set 3 | winnemucca
# Processing Record 30 of Set 3 | ponta do sol
# Processing Record 31 of Set 3 | avera
# Processing Record 32 of Set 3 | celestun
# Processing Record 33 of Set 3 | port lincoln
# Processing Record 34 of Set 3 | maunabo
# Processing Record 35 of Set 3 | la rioja
# Processing Record 36 of Set 3 | hithadhoo
# Processing Record 37 of Set 3 | maputo
# Processing Record 38 of Set 3 | fort saint john
# City not found. Skipping...
# Processing Record 39 of Set 3 | ossora
# Processing Record 40 of Set 3 | bosaso
# Processing Record 41 of Set 3 | kudahuvadhoo
# Processing Record 42 of Set 3 | campeche
# Processing Record 43 of Set 3 | lata
# Processing Record 44 of Set 3 | talnakh
# Processing Record 45 of Set 3 | airai
# Processing Record 46 of Set 3 | dikson
# Processing Record 47 of Set 3 | hamilton
# Processing Record 48 of Set 3 | shenjiamen
# Processing Record 49 of Set 3 | maine-soroa
# Processing Record 50 of Set 3 | hay river
# Processing Record 1 of Set 4 | daska
# Processing Record 2 of Set 4 | jamestown
# Processing Record 3 of Set 4 | palembang
# Processing Record 4 of Set 4 | saint-avertin
# Processing Record 5 of Set 4 | mao
# Processing Record 6 of Set 4 | bjerkvik
# Processing Record 7 of Set 4 | maniitsoq
# Processing Record 8 of Set 4 | san pedro
# Processing Record 9 of Set 4 | campina verde
# Processing Record 10 of Set 4 | atuona
# Processing Record 11 of Set 4 | palmerston
# Processing Record 12 of Set 4 | tautira
# Processing Record 13 of Set 4 | sao felix do xingu
# Processing Record 14 of Set 4 | coxim
# Processing Record 15 of Set 4 | sibolga
# Processing Record 16 of Set 4 | provideniya
# Processing Record 17 of Set 4 | taoudenni
# Processing Record 18 of Set 4 | novoagansk
# Processing Record 19 of Set 4 | idah
# Processing Record 20 of Set 4 | san patricio
# Processing Record 21 of Set 4 | tasiilaq
# Processing Record 22 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 4 | port blair
# Processing Record 24 of Set 4 | port hardy
# Processing Record 25 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 4 | burkhala
# City not found. Skipping...
# Processing Record 27 of Set 4 | maceio
# Processing Record 28 of Set 4 | abnub
# Processing Record 29 of Set 4 | santiago del estero
# Processing Record 30 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 4 | ayat
# Processing Record 32 of Set 4 | hobyo
# Processing Record 33 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 34 of Set 4 | manakara
# Processing Record 35 of Set 4 | ilhabela
# Processing Record 36 of Set 4 | vestmannaeyjar
# Processing Record 37 of Set 4 | egvekinot
# Processing Record 38 of Set 4 | shambu
# Processing Record 39 of Set 4 | chuy
# Processing Record 40 of Set 4 | nantucket
# Processing Record 41 of Set 4 | rock springs
# Processing Record 42 of Set 4 | luderitz
# Processing Record 43 of Set 4 | bethel
# Processing Record 44 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 4 | coruripe
# Processing Record 46 of Set 4 | tigre
# Processing Record 47 of Set 4 | souillac
# Processing Record 48 of Set 4 | salalah
# Processing Record 49 of Set 4 | presidente epitacio
# Processing Record 50 of Set 4 | isoka
# Processing Record 1 of Set 5 | sitka
# Processing Record 2 of Set 5 | tarauaca
# Processing Record 3 of Set 5 | sioux lookout
# Processing Record 4 of Set 5 | tommot
# Processing Record 5 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 6 of Set 5 | innisfail
# Processing Record 7 of Set 5 | taburao
# City not found. Skipping...
# Processing Record 8 of Set 5 | peleduy
# Processing Record 9 of Set 5 | marsh harbour
# Processing Record 10 of Set 5 | pevek
# Processing Record 11 of Set 5 | adrar
# Processing Record 12 of Set 5 | geraldton
# Processing Record 13 of Set 5 | acapulco
# Processing Record 14 of Set 5 | vieux-habitants
# Processing Record 15 of Set 5 | ribeira grande
# Processing Record 16 of Set 5 | kapit
# Processing Record 17 of Set 5 | kilindoni
# Processing Record 18 of Set 5 | vostok
# Processing Record 19 of Set 5 | saldanha
# Processing Record 20 of Set 5 | curup
# Processing Record 21 of Set 5 | strezhevoy
# Processing Record 22 of Set 5 | chirongui
# Processing Record 23 of Set 5 | santa lucia
# Processing Record 24 of Set 5 | nueva granada
# Processing Record 25 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 5 | almaznyy
# Processing Record 27 of Set 5 | kharp
# Processing Record 28 of Set 5 | ukiah
# Processing Record 29 of Set 5 | vardo
# Processing Record 30 of Set 5 | jalu
# Processing Record 31 of Set 5 | east london
# Processing Record 32 of Set 5 | margate
# Processing Record 33 of Set 5 | dabakala
# Processing Record 34 of Set 5 | sao joao evangelista
# Processing Record 35 of Set 5 | srednekolymsk
# Processing Record 36 of Set 5 | aksu
# Processing Record 37 of Set 5 | touros
# Processing Record 38 of Set 5 | hofn
# Processing Record 39 of Set 5 | mersing
# Processing Record 40 of Set 5 | lebu
# Processing Record 41 of Set 5 | la ronge
# Processing Record 42 of Set 5 | chateaubelair
# Processing Record 43 of Set 5 | haines junction
# Processing Record 44 of Set 5 | bahia blanca
# Processing Record 45 of Set 5 | sobolevo
# Processing Record 46 of Set 5 | khatanga
# Processing Record 47 of Set 5 | kalabo
# Processing Record 48 of Set 5 | torbay
# Processing Record 49 of Set 5 | vila
# Processing Record 50 of Set 5 | hambantota
# Processing Record 1 of Set 6 | san juan de la maguana
# Processing Record 2 of Set 6 | balimo
# City not found. Skipping...
# Processing Record 3 of Set 6 | fevralsk
# City not found. Skipping...
# Processing Record 4 of Set 6 | xining
# Processing Record 5 of Set 6 | bitlis
# Processing Record 6 of Set 6 | cherskiy
# Processing Record 7 of Set 6 | majene
# Processing Record 8 of Set 6 | cayenne
# Processing Record 9 of Set 6 | salinopolis
# Processing Record 10 of Set 6 | semporna
# Processing Record 11 of Set 6 | kashi
# Processing Record 12 of Set 6 | vao
# Processing Record 13 of Set 6 | samarai
# Processing Record 14 of Set 6 | ulaangom
# Processing Record 15 of Set 6 | puro
# Processing Record 16 of Set 6 | sorong
# Processing Record 17 of Set 6 | tual
# Processing Record 18 of Set 6 | catio
# Processing Record 19 of Set 6 | sao joao da barra
# Processing Record 20 of Set 6 | takoradi
# Processing Record 21 of Set 6 | vila velha
# Processing Record 22 of Set 6 | belaya gora
# Processing Record 23 of Set 6 | kieta
# Processing Record 24 of Set 6 | konstantinovka
# Processing Record 25 of Set 6 | saint-denis
# Processing Record 26 of Set 6 | nikki
# Processing Record 27 of Set 6 | cockburn harbour
# City not found. Skipping...
# Processing Record 28 of Set 6 | caernarfon
# Processing Record 29 of Set 6 | juneau
# Processing Record 30 of Set 6 | mitchell
# Processing Record 31 of Set 6 | nanortalik
# Processing Record 32 of Set 6 | gemunden
# Processing Record 33 of Set 6 | longyearbyen
# Processing Record 34 of Set 6 | omsukchan
# Processing Record 35 of Set 6 | westport
# Processing Record 36 of Set 6 | jibuti
# Processing Record 37 of Set 6 | san policarpo
# Processing Record 38 of Set 6 | cabo san lucas
# Processing Record 39 of Set 6 | shar
# Processing Record 40 of Set 6 | petatlan
# Processing Record 41 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 42 of Set 6 | ilulissat
# Processing Record 43 of Set 6 | fare
# Processing Record 44 of Set 6 | kireyevsk
# Processing Record 45 of Set 6 | yerbogachen
# Processing Record 46 of Set 6 | bathsheba
# Processing Record 47 of Set 6 | asfi
# Processing Record 48 of Set 6 | college
# Processing Record 49 of Set 6 | dhidhdhoo
# Processing Record 50 of Set 6 | yar-sale
# Processing Record 1 of Set 7 | usinsk
# Processing Record 2 of Set 7 | colares
# Processing Record 3 of Set 7 | salamiyah
# Processing Record 4 of Set 7 | pozo colorado
# Processing Record 5 of Set 7 | saint-georges
# Processing Record 6 of Set 7 | constitucion
# Processing Record 7 of Set 7 | east wenatchee bench
# Processing Record 8 of Set 7 | rosetta
# Processing Record 9 of Set 7 | alihe
# Processing Record 10 of Set 7 | poum
# Processing Record 11 of Set 7 | akyab
# Processing Record 12 of Set 7 | honningsvag
# Processing Record 13 of Set 7 | palanga
# Processing Record 14 of Set 7 | damara
# Processing Record 15 of Set 7 | cuamba
# Processing Record 16 of Set 7 | fairbanks
# Processing Record 17 of Set 7 | newport
# Processing Record 18 of Set 7 | isangel
# Processing Record 19 of Set 7 | nouadhibou
# Processing Record 20 of Set 7 | stornoway
# Processing Record 21 of Set 7 | kununurra
# Processing Record 22 of Set 7 | nijar
# Processing Record 23 of Set 7 | shitanjing
# Processing Record 24 of Set 7 | de-kastri
# Processing Record 25 of Set 7 | alice springs
# Processing Record 26 of Set 7 | kavaratti
# Processing Record 27 of Set 7 | teya
# Processing Record 28 of Set 7 | san cristobal
# Processing Record 29 of Set 7 | hailar
# Processing Record 30 of Set 7 | bongandanga
# Processing Record 31 of Set 7 | bani walid
# Processing Record 32 of Set 7 | ponta delgada
# Processing Record 33 of Set 7 | kijang
# Processing Record 34 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 7 | kloulklubed
# Processing Record 36 of Set 7 | buraydah
# Processing Record 37 of Set 7 | say
# Processing Record 38 of Set 7 | mabaruma
# Processing Record 39 of Set 7 | madimba
# Processing Record 40 of Set 7 | korem
# Processing Record 41 of Set 7 | sunamganj
# City not found. Skipping...
# Processing Record 42 of Set 7 | upernavik
# Processing Record 43 of Set 7 | lavrentiya
# Processing Record 44 of Set 7 | krasnodon
# Processing Record 45 of Set 7 | shache
# Processing Record 46 of Set 7 | emerald
# Processing Record 47 of Set 7 | sao filipe
# Processing Record 48 of Set 7 | magburaka
# Processing Record 49 of Set 7 | chokurdakh
# Processing Record 50 of Set 7 | san vicente
# Processing Record 1 of Set 8 | grindavik
# Processing Record 2 of Set 8 | ganzhou
# Processing Record 3 of Set 8 | kaeo
# Processing Record 4 of Set 8 | feicheng
# Processing Record 5 of Set 8 | conde
# Processing Record 6 of Set 8 | olga
# Processing Record 7 of Set 8 | brunico
# Processing Record 8 of Set 8 | caravelas
# Processing Record 9 of Set 8 | kirakira
# Processing Record 10 of Set 8 | nome
# Processing Record 11 of Set 8 | altay
# Processing Record 12 of Set 8 | sinnamary
# Processing Record 13 of Set 8 | shingu
# Processing Record 14 of Set 8 | faanui
# Processing Record 15 of Set 8 | chimbote
# Processing Record 16 of Set 8 | palmer
# Processing Record 17 of Set 8 | tiksi
# Processing Record 18 of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record 19 of Set 8 | jinchang
# Processing Record 20 of Set 8 | codrington
# Processing Record 21 of Set 8 | chumikan
# Processing Record 22 of Set 8 | visnes
# Processing Record 23 of Set 8 | griffith
# Processing Record 24 of Set 8 | itupiranga
# Processing Record 25 of Set 8 | oppdal
# Processing Record 26 of Set 8 | birin
# Processing Record 27 of Set 8 | sao jose da coroa grande
# Processing Record 28 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 8 | coihaique
# Processing Record 30 of Set 8 | mogadishu
# Processing Record 31 of Set 8 | daud khel
# Processing Record 32 of Set 8 | ondjiva
# Processing Record 33 of Set 8 | karratha
# Processing Record 34 of Set 8 | esperance
# Processing Record 35 of Set 8 | clyde river
# Processing Record 36 of Set 8 | kruisfontein
# Processing Record 37 of Set 8 | westpunt
# City not found. Skipping...
# Processing Record 38 of Set 8 | belmonte
# Processing Record 39 of Set 8 | matagami
# Processing Record 40 of Set 8 | nago
# Processing Record 41 of Set 8 | kahului
# Processing Record 42 of Set 8 | cap-aux-meules
# Processing Record 43 of Set 8 | yangambi
# Processing Record 44 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 8 | cootamundra
# Processing Record 46 of Set 8 | husavik
# Processing Record 47 of Set 8 | rio grande
# Processing Record 48 of Set 8 | kurchum
# Processing Record 49 of Set 8 | mount gambier
# Processing Record 50 of Set 8 | agrado
# Processing Record 1 of Set 9 | opuwo
# Processing Record 2 of Set 9 | mitu
# Processing Record 3 of Set 9 | yuci
# Processing Record 4 of Set 9 | jiayuguan
# Processing Record 5 of Set 9 | skibbereen
# Processing Record 6 of Set 9 | dordrecht
# Processing Record 7 of Set 9 | rio gallegos
# Processing Record 8 of Set 9 | batemans bay
# Processing Record 9 of Set 9 | ketchikan
# Processing Record 10 of Set 9 | ulladulla
# Processing Record 11 of Set 9 | villeta
# Processing Record 12 of Set 9 | port-gentil
# Processing Record 13 of Set 9 | namibe
# Processing Record 14 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 15 of Set 9 | dunmore town
# Processing Record 16 of Set 9 | potam
# Processing Record 17 of Set 9 | vila franca do campo
# Processing Record 18 of Set 9 | samana
# Processing Record 19 of Set 9 | weligama
# Processing Record 20 of Set 9 | calama
# Processing Record 21 of Set 9 | ereymentau
# Processing Record 22 of Set 9 | kroya
# Processing Record 23 of Set 9 | lasa
# Processing Record 24 of Set 9 | tammisaari
# Processing Record 25 of Set 9 | san ignacio
# Processing Record 26 of Set 9 | cosolapa
# Processing Record 27 of Set 9 | pangnirtung
# Processing Record 28 of Set 9 | marawi
# Processing Record 29 of Set 9 | kropotkin
# Processing Record 30 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 31 of Set 9 | sayyan
# Processing Record 32 of Set 9 | hauterive
# Processing Record 33 of Set 9 | lillooet
# Processing Record 34 of Set 9 | gizo
# Processing Record 35 of Set 9 | panaba
# Processing Record 36 of Set 9 | trairi
# Processing Record 37 of Set 9 | goure
# Processing Record 38 of Set 9 | visconde do rio branco
# Processing Record 39 of Set 9 | lagoa
# Processing Record 40 of Set 9 | cidreira
# Processing Record 41 of Set 9 | lake city
# Processing Record 42 of Set 9 | mount isa
# Processing Record 43 of Set 9 | nuuk
# Processing Record 44 of Set 9 | at-bashi
# Processing Record 45 of Set 9 | marrakesh
# Processing Record 46 of Set 9 | berlevag
# Processing Record 47 of Set 9 | iskateley
# Processing Record 48 of Set 9 | la pena
# Processing Record 49 of Set 9 | gusau
# Processing Record 50 of Set 9 | danane
# Processing Record 1 of Set 10 | tafresh
# Processing Record 2 of Set 10 | gallup
# Processing Record 3 of Set 10 | zeya
# Processing Record 4 of Set 10 | tikrit
# Processing Record 5 of Set 10 | rosarito
# Processing Record 6 of Set 10 | shimoda
# Processing Record 7 of Set 10 | demirci
# Processing Record 8 of Set 10 | neiafu
# Processing Record 9 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 10 of Set 10 | suoyarvi
# Processing Record 11 of Set 10 | eyl
# Processing Record 12 of Set 10 | lons-le-saunier
# Processing Record 13 of Set 10 | las vegas
# Processing Record 14 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 15 of Set 10 | guozhen
# Processing Record 16 of Set 10 | halifax
# Processing Record 17 of Set 10 | mareeba
# Processing Record 18 of Set 10 | sombrerete
# Processing Record 19 of Set 10 | jucurutu
# Processing Record 20 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 21 of Set 10 | lota
# Processing Record 22 of Set 10 | makakilo city
# Processing Record 23 of Set 10 | tabou
# Processing Record 24 of Set 10 | port said
# Processing Record 25 of Set 10 | togur
# Processing Record 26 of Set 10 | madang
# Processing Record 27 of Set 10 | wanning
# Processing Record 28 of Set 10 | nordborg
# Processing Record 29 of Set 10 | igarka
# Processing Record 30 of Set 10 | vredendal
# Processing Record 31 of Set 10 | el alto
# Processing Record 32 of Set 10 | asau
# Processing Record 33 of Set 10 | sahuaripa
# Processing Record 34 of Set 10 | erzin
# Processing Record 35 of Set 10 | caldwell
# Processing Record 36 of Set 10 | port alberni
# Processing Record 37 of Set 10 | ust-nera
# Processing Record 38 of Set 10 | oriximina
# Processing Record 39 of Set 10 | bubaque
# Processing Record 40 of Set 10 | shamary
# Processing Record 41 of Set 10 | ahipara
# Processing Record 42 of Set 10 | komsomolskiy
# Processing Record 43 of Set 10 | olinda
# Processing Record 44 of Set 10 | alugan
# Processing Record 45 of Set 10 | mtwara
# Processing Record 46 of Set 10 | gallipoli
# Processing Record 47 of Set 10 | kon tum
# Processing Record 48 of Set 10 | plettenberg bay
# Processing Record 49 of Set 10 | lethem
# Processing Record 50 of Set 10 | andenes
# Processing Record 1 of Set 11 | horsham
# Processing Record 2 of Set 11 | naze
# Processing Record 3 of Set 11 | tolaga bay
# Processing Record 4 of Set 11 | gorontalo
# Processing Record 5 of Set 11 | qaqortoq
# Processing Record 6 of Set 11 | gaoua
# Processing Record 7 of Set 11 | half moon bay
# Processing Record 8 of Set 11 | culebra
# Processing Record 9 of Set 11 | cortez
# Processing Record 10 of Set 11 | tsabong
# Processing Record 11 of Set 11 | kuusamo
# Processing Record 12 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 11 | freeport
# Processing Record 14 of Set 11 | paciran
# Processing Record 15 of Set 11 | necochea
# Processing Record 16 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 17 of Set 11 | beringovskiy
# Processing Record 18 of Set 11 | pasighat
# Processing Record 19 of Set 11 | yulara
# Processing Record 20 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 11 | verkhoyansk
# Processing Record 22 of Set 11 | gurupa
# Processing Record 23 of Set 11 | votkinsk
# Processing Record 24 of Set 11 | davila
# Processing Record 25 of Set 11 | karatu
# Processing Record 26 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 27 of Set 11 | nara
# Processing Record 28 of Set 11 | bari sadri
# Processing Record 29 of Set 11 | elko
# Processing Record 30 of Set 11 | ola
# Processing Record 31 of Set 11 | bonavista
# Processing Record 32 of Set 11 | nakhon phanom
# Processing Record 33 of Set 11 | lichtenburg
# Processing Record 34 of Set 11 | alindao
# Processing Record 35 of Set 11 | sola
# Processing Record 36 of Set 11 | longonjo
# Processing Record 37 of Set 11 | newtonhill
# Processing Record 38 of Set 11 | cockburn town
# Processing Record 39 of Set 11 | volosovo
# Processing Record 40 of Set 11 | boden
# Processing Record 41 of Set 11 | wexford
# Processing Record 42 of Set 11 | vorotynets
# Processing Record 43 of Set 11 | san lawrenz
# Processing Record 44 of Set 11 | tukrah
# Processing Record 45 of Set 11 | pahrump
# Processing Record 46 of Set 11 | quatre cocos
# Processing Record 47 of Set 11 | carutapera
# Processing Record 48 of Set 11 | arua
# Processing Record 49 of Set 11 | kamyshevatskaya
# Processing Record 50 of Set 11 | mecca
# Processing Record 1 of Set 12 | pedernales
# Processing Record 2 of Set 12 | bilibino
# Processing Record 3 of Set 12 | brinkovskaya
# Processing Record 4 of Set 12 | yarim
# Processing Record 5 of Set 12 | yanan
# City not found. Skipping...
# Processing Record 6 of Set 12 | saint anthony
# Processing Record 7 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 8 of Set 12 | liverpool
# Processing Record 9 of Set 12 | sabha
# Processing Record 10 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 11 of Set 12 | ozgon
# City not found. Skipping...
# Processing Record 12 of Set 12 | tucuman
# Processing Record 13 of Set 12 | mantua
# Processing Record 14 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 15 of Set 12 | santo domingo
# Processing Record 16 of Set 12 | korla
# Processing Record 17 of Set 12 | myitkyina
# Processing Record 18 of Set 12 | neftcala
# Processing Record 19 of Set 12 | mocuba
# Processing Record 20 of Set 12 | daru
# Processing Record 21 of Set 12 | los llanos de aridane
# Processing Record 22 of Set 12 | khandyga
# Processing Record 23 of Set 12 | fasa
# Processing Record 24 of Set 12 | hirara
# Processing Record 25 of Set 12 | peniche
# Processing Record 26 of Set 12 | collie
# Processing Record 27 of Set 12 | teknaf
# Processing Record 28 of Set 12 | hami
# Processing Record 29 of Set 12 | puno
# Processing Record 30 of Set 12 | ambon
# Processing Record 31 of Set 12 | sao sebastiao
# Processing Record 32 of Set 12 | tiruchchirappalli
# Processing Record 33 of Set 12 | sambava
# Processing Record 34 of Set 12 | faya
# Processing Record 35 of Set 12 | wadi musa
# Processing Record 36 of Set 12 | leninsk
# Processing Record 37 of Set 12 | petauke
# Processing Record 38 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 39 of Set 12 | chifeng
# Processing Record 40 of Set 12 | kushmurun
# Processing Record 41 of Set 12 | logansport
# Processing Record 42 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 43 of Set 12 | pacific grove
# Processing Record 44 of Set 12 | moree
# Processing Record 45 of Set 12 | nalut
# Processing Record 46 of Set 12 | puerto carreno
# Processing Record 47 of Set 12 | tabasalu
# Processing Record 48 of Set 12 | mwinilunga
# Processing Record 49 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 50 of Set 12 | phan thiet
# Processing Record 1 of Set 13 | beira
# Processing Record 2 of Set 13 | chase
# Processing Record 3 of Set 13 | san andres
# Processing Record 4 of Set 13 | twin falls
# Processing Record 5 of Set 13 | coquimbo
# Processing Record 6 of Set 13 | comodoro rivadavia
# Processing Record 7 of Set 13 | hoghiz
# Processing Record 8 of Set 13 | heishan
# Processing Record 9 of Set 13 | albanel
# Processing Record 10 of Set 13 | broome
# Processing Record 11 of Set 13 | tambacounda
# Processing Record 12 of Set 13 | kenora
# Processing Record 13 of Set 13 | kandi
# Processing Record 14 of Set 13 | gorkovskoye
# City not found. Skipping...
# Processing Record 15 of Set 13 | sfantu gheorghe
# Processing Record 16 of Set 13 | kuryk
# Processing Record 17 of Set 13 | flinders
# Processing Record 18 of Set 13 | lakes entrance
# Processing Record 19 of Set 13 | porto velho
# Processing Record 20 of Set 13 | biltine
# Processing Record 21 of Set 13 | port hedland
# Processing Record 22 of Set 13 | sulina
# Processing Record 23 of Set 13 | ginda
# Processing Record 24 of Set 13 | araouane
# Processing Record 25 of Set 13 | cozumel
# Processing Record 26 of Set 13 | ambilobe
# Processing Record 27 of Set 13 | seydi
# Processing Record 28 of Set 13 | townsville
# Processing Record 29 of Set 13 | tallahassee
# Processing Record 30 of Set 13 | malayal
# Processing Record 31 of Set 13 | ugoofaaru
# Processing Record 32 of Set 13 | verkhnyaya inta
# Processing Record 33 of Set 13 | kasama
# Processing Record 34 of Set 13 | mehamn
# Processing Record 35 of Set 13 | oktyabrskiy
# Processing Record 36 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 37 of Set 13 | ankang
# Processing Record 38 of Set 13 | el reno
# Processing Record 39 of Set 13 | padang
# Processing Record 40 of Set 13 | trinidad
# Processing Record 41 of Set 13 | sri aman
# Processing Record 42 of Set 13 | guajara-mirim
# City not found. Skipping...
# Processing Record 43 of Set 13 | kanye
# Processing Record 44 of Set 13 | ucluelet
# Processing Record 45 of Set 13 | mubi
# Processing Record 46 of Set 13 | mahibadhoo
# Processing Record 47 of Set 13 | tessalit
# Processing Record 48 of Set 13 | ejby
# Processing Record 49 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 50 of Set 13 | mandalgovi
# Processing Record 1 of Set 14 | lumeje
# Processing Record 2 of Set 14 | singapore
# Processing Record 3 of Set 14 | chapais
# Processing Record 4 of Set 14 | denpasar
# Processing Record 5 of Set 14 | mount hagen
# Processing Record 6 of Set 14 | iberia
# Processing Record 7 of Set 14 | iranshahr
# Processing Record 8 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 14 | malanje
# Processing Record 10 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 11 of Set 14 | kungurtug
# Processing Record 12 of Set 14 | belize
# Processing Record 13 of Set 14 | angoche
# Processing Record 14 of Set 14 | booue
# Processing Record 15 of Set 14 | cobija
# Processing Record 16 of Set 14 | zhigansk
# Processing Record 17 of Set 14 | whitehorse
# Processing Record 18 of Set 14 | hakui
# Processing Record 19 of Set 14 | saint-francois
# Processing Record 20 of Set 14 | baykit
# Processing Record 21 of Set 14 | dalby
# Processing Record 22 of Set 14 | havre-saint-pierre
# Processing Record 23 of Set 14 | topolobampo
# Processing Record 24 of Set 14 | oussouye
# Processing Record 25 of Set 14 | tiarei
# Processing Record 26 of Set 14 | sukumo
# Processing Record 27 of Set 14 | el sauzal
# Processing Record 28 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 29 of Set 14 | lyuban
# Processing Record 30 of Set 14 | thakurganj
# Processing Record 31 of Set 14 | udachnyy
# Processing Record 32 of Set 14 | xochitlan
# Processing Record 33 of Set 14 | man
# Processing Record 34 of Set 14 | praxedis guerrero
# Processing Record 35 of Set 14 | comiso
# Processing Record 36 of Set 14 | ortona
# Processing Record 37 of Set 14 | greencastle
# Processing Record 38 of Set 14 | bireun
# Processing Record 39 of Set 14 | bilma
# Processing Record 40 of Set 14 | saint-pierre
# Processing Record 41 of Set 14 | koungheul
# Processing Record 42 of Set 14 | kodinsk
# Processing Record 43 of Set 14 | vilyuysk
# Processing Record 44 of Set 14 | bukama
# Processing Record 45 of Set 14 | galle
# Processing Record 46 of Set 14 | villa carlos paz
# Processing Record 47 of Set 14 | yang talat
# Processing Record 48 of Set 14 | sibu
# Processing Record 49 of Set 14 | saint-joseph
# Processing Record 50 of Set 14 | cape coast
# Processing Record 1 of Set 15 | aswan
# Processing Record 2 of Set 15 | krasnyy oktyabr
# Processing Record 3 of Set 15 | waiouru
# Processing Record 4 of Set 15 | mbumi
# Processing Record 5 of Set 15 | forest lake
# Processing Record 6 of Set 15 | isiro
# Processing Record 7 of Set 15 | bambanglipuro
# Processing Record 8 of Set 15 | kulob
# Processing Record 9 of Set 15 | geri
# Processing Record 10 of Set 15 | tempio pausania
# Processing Record 11 of Set 15 | kommunisticheskiy
# Processing Record 12 of Set 15 | mazagao
# Processing Record 13 of Set 15 | tura
# Processing Record 14 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 15 of Set 15 | arman
# Processing Record 16 of Set 15 | arlit
# Processing Record 17 of Set 15 | kadirli
# Processing Record 18 of Set 15 | dali
# Processing Record 19 of Set 15 | seaside
# Processing Record 20 of Set 15 | vaitape
# Processing Record 21 of Set 15 | srandakan
# Processing Record 22 of Set 15 | tromso
# Processing Record 23 of Set 15 | azimur
# City not found. Skipping...
# Processing Record 24 of Set 15 | kyzyl-suu
# Processing Record 25 of Set 15 | port moresby
# Processing Record 26 of Set 15 | norman wells
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Avarua      CK -21.2078 -159.7750     82.45        78          75
# 1     Cape Town      ZA -33.9258   18.4232     68.34        69          78
# 2      Thompson      CA  55.7435  -97.8558    -14.78        97         100
# 3      Katsuura      JP  35.1333  140.3000     41.14        39           0
# 4        Hobart      AU -42.8794  147.3294     73.06        50          20
# 5  Umm Kaddadah      SD  13.6017   26.6876     55.00        25          30
# 6        Hasaki      JP  35.7333  140.8333     41.29        35           0
# 7           Ler      SS   8.3018   30.1418     71.56        17          13
# 8       Mataura      NZ -46.1927  168.8643     56.48        44          43
# 9       Kavieng      PG  -2.5744  150.7967     83.91        73         100
#
#    Wind Speed Current Description
# 0       17.27       broken clouds
# 1        4.03       broken clouds
# 2        3.33     overcast clouds
# 3       11.10           clear sky
# 4        1.01          few clouds
# 5       17.65    scattered clouds
# 6       13.78           clear sky
# 7        8.93          few clouds
# 8        3.65    scattered clouds
# 9        7.43     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
